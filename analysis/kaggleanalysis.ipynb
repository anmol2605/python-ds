# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
DS_salary = pd.read_excel('DS salary.xlsx')

# %%
DS_salary
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
DS_salary.head(5)
# Out:
#    work_year experience_level employment_type                job_title  \
# 0       2023               EN              FT        Applied Scientist
# 1       2023               EN              FT        Applied Scientist
# 2       2023               EN              FT     Data Quality Analyst
# 3       2023               EN              FT  Compliance Data Analyst
# 4       2023               EN              FT        Applied Scientist
#
#    salary salary_currency  salary_in_usd company_location company_size
# 0  213660             USD         213660               US            L
# 1  130760             USD         130760               US            L
# 2  100000             USD         100000               NG            L
# 3   30000             USD          30000               NG            L
# 4  204620             USD         204620               US            L

# %%
DS_salary.sample()
# Out:
#       work_year experience_level employment_type       job_title  salary  \
# 3688       2020               EN              FT  Data Scientist   43200
#
#      salary_currency  salary_in_usd company_location company_size
# 3688             EUR          49268               DE            S

# %%
DS_salary['job_title']
# Out:
# 0               Applied Scientist
# 1               Applied Scientist
# 2            Data Quality Analyst
# 3         Compliance Data Analyst
# 4               Applied Scientist
#                   ...
# 3756     Principal Data Scientist
# 3757               Data Scientist
# 3758         Data Science Manager
# 3759    Machine Learning Engineer
# 3760               Data Scientist
# Name: job_title, Length: 3761, dtype: object

# %%
DS_salary['work_year']
# Out:
# 0       2023
# 1       2023
# 2       2023
# 3       2023
# 4       2023
#         ...
# 3756    2020
# 3757    2020
# 3758    2020
# 3759    2020
# 3760    2020
# Name: work_year, Length: 3761, dtype: int64

# %%
DS_salary['experience_level']
# Out:
# 0       EN
# 1       EN
# 2       EN
# 3       EN
# 4       EN
#         ..
# 3756    SE
# 3757    SE
# 3758    SE
# 3759    SE
# 3760    SE
# Name: experience_level, Length: 3761, dtype: object

# %%
cols = ['job_title','experience_level','work_year']
DS_salary[cols]
# Out:
#                       job_title experience_level  work_year
# 0             Applied Scientist               EN       2023
# 1             Applied Scientist               EN       2023
# 2          Data Quality Analyst               EN       2023
# 3       Compliance Data Analyst               EN       2023
# 4             Applied Scientist               EN       2023
# ...                         ...              ...        ...
# 3756   Principal Data Scientist               SE       2020
# 3757             Data Scientist               SE       2020
# 3758       Data Science Manager               SE       2020
# 3759  Machine Learning Engineer               SE       2020
# 3760             Data Scientist               SE       2020
#
# [3761 rows x 3 columns]

# %%
DS_salary.iloc[26]
# Out:
# work_year                       2023
# experience_level                  EN
# employment_type                   FT
# job_title           BI Data Engineer
# salary                         60000
# salary_currency                  USD
# salary_in_usd                  60000
# company_location                  US
# company_size                       M
# Name: 26, dtype: object

# %%
DS_salary.iloc[46,4]
# Out:
# 75000

# %%
DS_salary.iloc[40,3:]
# Out:
# job_title           Autonomous Vehicle Technician
# salary                                       7000
# salary_currency                               USD
# salary_in_usd                                7000
# company_location                               GH
# company_size                                    S
# Name: 40, dtype: object

# %%
cols = ['work_year','salary_in_usd']
DS_salary[cols].plot(kind = 'area')
# Out:
# <Axes: >

# %%
DS_salary.set_index('job_title')
# Out:
#                            work_year experience_level employment_type  salary  \
# job_title
# Applied Scientist               2023               EN              FT  213660
# Applied Scientist               2023               EN              FT  130760
# Data Quality Analyst            2023               EN              FT  100000
# Compliance Data Analyst         2023               EN              FT   30000
# Applied Scientist               2023               EN              FT  204620
# ...                              ...              ...             ...     ...
# Principal Data Scientist        2020               SE              FT  130000
# Data Scientist                  2020               SE              FT   80000
# Data Science Manager            2020               SE              FT  190200
# Machine Learning Engineer       2020               SE              FT   40000
# Data Scientist                  2020               SE              FT  412000
#
# ...

# %%
DS_salary.index
# Out:
# RangeIndex(start=0, stop=3761, step=1)

# %%
DS_salary.set_index('job_title', inplace = True)

# %%
DS_salary
# Out:
#                            work_year experience_level employment_type  salary  \
# job_title
# Applied Scientist               2023               EN              FT  213660
# Applied Scientist               2023               EN              FT  130760
# Data Quality Analyst            2023               EN              FT  100000
# Compliance Data Analyst         2023               EN              FT   30000
# Applied Scientist               2023               EN              FT  204620
# ...                              ...              ...             ...     ...
# Principal Data Scientist        2020               SE              FT  130000
# Data Scientist                  2020               SE              FT   80000
# Data Science Manager            2020               SE              FT  190200
# Machine Learning Engineer       2020               SE              FT   40000
# Data Scientist                  2020               SE              FT  412000
#
# ...

# %%
DS_salary.sort_index(ascending = False)
# Out:
#                                work_year experience_level employment_type  \
# job_title
# Staff Data Scientist                2021               SE              CT
# Staff Data Analyst                  2020               EX              FT
# Software Data Engineer              2023               SE              FL
# Software Data Engineer              2023               MI              FT
# Research Scientist                  2023               MI              FT
# ...                                  ...              ...             ...
# AI Developer                        2022               EN              FT
# 3D Computer Vision Researcher       2021               EN              FT
# 3D Computer Vision Researcher       2022               EN              FT
# 3D Computer Vision Researcher       2022               SE              FT
# 3D Computer Vision Researcher       2021               MI              PT
#
# ...

# %%
DS_salary.sort_values(by = 'salary', inplace = True)

# %%
DS_salary
# Out:
#                                 work_year experience_level employment_type  \
# job_title
# AI Developer                         2022               EN              FT
# Autonomous Vehicle Technician        2023               EN              FT
# Analytics Engineer                   2022               MI              CT
# Data Analyst                         2020               MI              FT
# Product Data Scientist               2022               SE              FT
# ...                                   ...              ...             ...
# Lead Machine Learning Engineer       2022               SE              FT
# ML Engineer                          2021               MI              FT
# Data Scientist                       2020               MI              FT
# BI Data Analyst                      2021               MI              FT
# Data Scientist                       2021               MI              FT
#
# ...

# %%
DS_salary.sort_values(by = 'work_year', inplace = True)

# %%
DS_salary
# Out:
#                            work_year experience_level employment_type  \
# job_title
# Data Scientist                  2020               SE              FT
# Data Engineer                   2020               EN              FT
# Big Data Engineer               2020               SE              FT
# Data Engineer                   2020               MI              FT
# Business Data Analyst           2020               EN              CT
# ...                              ...              ...             ...
# Data Scientist                  2023               SE              FT
# Data Engineer                   2023               MI              FT
# Research Scientist              2023               SE              FT
# Machine Learning Engineer       2023               MI              FT
# Data Engineer                   2023               SE              FT
#
#                             salary salary_currency  salary_in_usd  \
# job_title
# ...

# %%
DS_salary.sort_values(by=['job_title','salary'], ascending = [True, False])
# Out:
#                                work_year experience_level employment_type  \
# job_title
# 3D Computer Vision Researcher       2021               MI              PT
# 3D Computer Vision Researcher       2022               EN              FT
# 3D Computer Vision Researcher       2021               EN              FT
# 3D Computer Vision Researcher       2022               SE              FT
# AI Developer                        2022               EN              FT
# ...                                  ...              ...             ...
# Research Scientist                  2022               MI              FT
# Software Data Engineer              2023               MI              FT
# Software Data Engineer              2023               SE              FL
# Staff Data Analyst                  2020               EX              FT
# Staff Data Scientist                2021               SE              CT
#
# ...

# %%
DS_salary.describe()
# Out:
#          work_year        salary  salary_in_usd
# count  3761.000000  3.761000e+03    3761.000000
# mean   2022.374103  1.905999e+05  137555.178942
# std       0.691252  6.711457e+05   63022.267974
# min    2020.000000  6.000000e+03    5132.000000
# 25%    2022.000000  1.000000e+05   95000.000000
# 50%    2022.000000  1.375000e+05  135000.000000
# 75%    2023.000000  1.800000e+05  175000.000000
# max    2023.000000  3.040000e+07  450000.000000

# %%
DS_salary['salary'].value_counts()
# Out:
# salary
# 100000    112
# 150000    100
# 120000     99
# 160000     85
# 130000     85
#          ...
# 154560      1
# 13000       1
# 26000       1
# 149000      1
# 178000      1
# Name: count, Length: 817, dtype: int64

# %%
DS_salary.groupby('company_size').get_group('L')
# Out:
#                                     work_year experience_level  \
# job_title
# Data Engineer                            2020               EN
# Data Engineer                            2020               MI
# Business Data Analyst                    2020               EN
# Lead Data Analyst                        2020               MI
# Data Analyst                             2020               EN
# ...                                       ...              ...
# Data Engineer                            2023               MI
# Azure Data Engineer                      2023               SE
# Data Analyst                             2023               EN
# Data Quality Analyst                     2023               EN
# Applied Machine Learning Scientist       2023               SE
#
#                                    employment_type   salary salary_currency  \
# job_title
# Data Engineer                                   FT  1000000             INR
# ...
