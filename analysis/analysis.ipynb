# %% [markdown]
# - matplotlib (basic visualization)
# - seaborn (advanced visualization)
# - plotly (interactive visualizationA)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins['bill_depth_mm'].plot(linestyle = '', marker = 's', markersize = 10, alpha = 0.5, figsize = (10,5),
                                markerfacecolor = 'yellow',
                                markeredgecolor = 'black'
                                )
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'][:50].plot(kind= 'bar', figsize = (15,5),color = 'green')
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'][:50].plot(kind= 'area',alpha = 0.5, figsize = (15,5),color = 'green')
# Out:
# <Axes: >

# %%
print(sns.get_dataset_names())
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\HP\miniconda3\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\Users\HP\miniconda3\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\HP\miniconda3\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# ...

# %%
penguins.plot(kind = 'scatter', x = 'bill_length_mm', y = 'bill_depth_mm', s = 100,alpha = 0.5)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# Subplots

# %%
fig, axs = plt.subplots(1,2,figsize = (15,5), constrained_layout = True)
penguins.plot(kind = 'scatter', x = 'bill_length_mm', y = 'bill_depth_mm', s = 100,alpha = 0.5,color = 'red', ax = axs[0], title= ' penguin_bill_data')
penguins.plot(kind = 'scatter', x = 'bill_length_mm', y = 'flipper_length_mm', s = 100,alpha = 0.5, ax = axs[1], title= 'penguin flipper')
plt.show()

# %%
penguins['species'].value_counts().plot(kind='pie',
                                        autopct = '%1.1f%%',
                                        figsize = (3,3),
                                        title = 'Species',
                                        ylabel='')
# Out:
# <Axes: title={'center': 'Species'}>

# %%
penguins['species'].value_counts().plot(kind='pie',
                                        autopct = '%1.1f%%',
                                        figsize = (3,3),
                                        title = 'Species',
                                        ylabel='',
                                        pctdistance = .7,
                                        wedgeprops = dict(width = 0.5)
                                        )
# Out:
# <Axes: title={'center': 'Species'}>

# %% [markdown]
# Advanced visualization

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(data=tips, x ='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data = tips, x ='sex', hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.displot(data=tips, x='total_bill', binwidth = 3)  #distribution of data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sns.displot(data=tips, x='total_bill', binwidth = 3)
#
# NameError: name 'tips' is not defined

# %%
sns.displot(data = tips, x = 'total_bill', col= 'sex')
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data = tips, x = 'total_bill', row= 'sex')
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data = tips, x = 'total_bill', col = 'smoker', row = 'sex')
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data = tips, x= 'total_bill', col='smoker', row= 'sex', height = 3, kind = 'kde')
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data = tips, x= 'total_bill', col='smoker', row= 'sex', height = 3, kind = 'kde', hue='day', multiple = 'stack')
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", element="step")
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(penguins, x="flipper_length_mm", kind="kde", bw_adjust=2)
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm")
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="kde")
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(penguins)
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.PairGrid(penguins)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
sns.color_palette("Paired")
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 1.0, 0.6),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %%
sns.catplot(data=tips, x="day", y="total_bill", jitter=False)
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=tips, x="day", y="total_bill", kind="swarm")
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=tips, x="day", y="total_bill", kind="box")
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=tips, x="day", y="total_bill", hue="smoker", kind="box")
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
diamonds = sns.load_dataset("diamonds")
sns.catplot(
    data=diamonds.sort_values("color"),
    x="color", y="price", kind="boxen",
)
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(
    data=tips, x="day", y="total_bill", hue="sex",
    kind="violin", split=True,
)
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(
    data=tips, x="day", y="total_bill", hue="sex",
    kind="violin", inner="stick", split=True, palette="pastel",
)
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.catplot(data=tips, x="day", y="total_bill", kind="violin", inner=None)
sns.swarmplot(data=tips, x="day", y="total_bill", color="k", size=3, ax=g.ax)
# Out:
# c:\Users\HP\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <Axes: xlabel='day', ylabel='total_bill'>
